# %%
import tensorflow as tf
import numpy as np
import os
import pathlib
import time
import datetime
import tf_slim as slim
import cv2
from matplotlib import pyplot as plt
from IPython import display
import sys
sys.path.append('PbLite-Contour-Detection/Code')
import PbLite

# %%
PBImage = PbLite.PbLite(str(0),r'E:\GUC files\semester 9\CV\Contour Detection and image segmentation\project_dataset\images\train\66075.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12020/2172738391.py in <module>
# ----> 1 PBImage = PbLite.PbLite(str(0),r'E:\GUC files\semester 9\CV\Contour Detection and image segmentation\project_dataset\images\train\66075.jpg')
#
# E:\GUC files\semester 9\CV\Contour Detection and image segmentation\PbLite-Contour-Detection/Code\PbLite.py in PbLite(ImageName, ImagePath)
#     511                           ColorGradient)/(3.0), w1*CannyBaselineImage + w2*SobelBaselineImage)
#     512
# --> 513     plt.imsave(os.path.join(ResultsPath, PbLiteName), PbLite, cmap='gray')
#     514
#     515     return PbLite;
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\pyplot.py in imsave(fname, arr, **kwargs)
#    2142 @_copy_docstring_and_deprecators(matplotlib.image.imsave)
#    2143 def imsave(fname, arr, **kwargs):
# ...

# %%
def auto_canny(image, sigma=0.33):
    # compute the median of the single channel pixel intensities
    #v = np.median(image)
    # apply automatic Canny edge detection using the computed median
    #lower = int(max(0, (1.0 - sigma) * v))
    #upper = int(min(255, (1.0 + sigma) * v))
    
    ret2,th2 = cv2.threshold(image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    lower = ret2//2
    upper = ret2
    image = cv2.GaussianBlur(image,(5,5),0)
    image = cv2.GaussianBlur(image,(5,5),0)
    edged = cv2.Canny(image, lower, upper)
    #edged = cv2.dilate(edged, np.ones((3,3)),iterations = 1)
   
    # return the edged image
    return edged

# %%
image = cv2.imread(r'E:\GUC files\semester 9\CV\Contour Detection and image segmentation\project_dataset\images\train\100080.jpg',0)
plt.imshow(auto_canny(image),cmap = 'gray')

# %%
Image_gray = image
#Image_gray = cv2.GaussianBlur(Image_gray,(3,3),0)
img_sobel3_x = cv2.Sobel(Image_gray, cv2.CV_8U, dx=1, dy=0, ksize=3)
img_sobel3_y = cv2.Sobel(Image_gray, cv2.CV_8U, dx=0, dy=1, ksize=3)

SobelBaselineImage = img_sobel3_x + img_sobel3_y
#SobelBaselineImage = cv2.dilate(SobelBaselineImage, np.ones((3,3)),iterations = 1)   
plt.imshow(SobelBaselineImage,cmap='gray')

# %%
# Out:
# The filename, directory name, or volume label syntax is incorrect.
